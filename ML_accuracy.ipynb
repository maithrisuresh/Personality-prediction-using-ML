# %%
import pandas as pd

# %%
personality=pd.read_csv("cleaned_data_new.csv")

# %%
personality.drop(['Unnamed: 0'],axis=1)
# Out:
#       type  Extrovert  Sensing  Thinking  Judging  \
# 0     INFJ          0        0         0        1
# 1     INFJ          0        0         0        1
# 2     INFJ          0        0         0        1
# 3     ENFJ          1        0         0        1
# 4     INTP          0        0         1        0
# ...    ...        ...      ...       ...      ...
# 8583  INFP          0        0         0        0
# 8584  ENFP          1        0         0        0
# 8585  INTP          0        0         1        0
# 8586  INFP          0        0         0        0
# 8587  ENTP          1        0         1        0
#
#                                                   posts  \
# 0     'When asked of the things you wish you did ear...
# 1     'I love both and they are equally important to...
# 2     Really? You think implying that everyone who i...
# 3     'Love is a crazy thing.   Se is our best form ...
# 4     'I am a physics undergrad with a computation e...
# ...                                                 ...
# 8583  'I have almost no self confidence. I feel like...
# 8584  'Oh man, I guess I gotta knock back that 100% ...
# 8585  'HAL, im gel. This one is of the 'Blood Moon' ...
# 8586  'Like BilgePump, I was also a late bloomer whe...
# 8587  'It happens to me.  I feel compelled to help p...
#
#                                           cleaned_posts  compound--sentiment  \
# 0      asked thing wish earlier       find answering...             0.999800
# 1      love equally important  music window soul  in...             0.999950
# 2     really  think implying everyone entrepreneur s...             0.995499
# 3      love crazy thing     best form communication ...             0.999700
# 4      physic undergrad computation emphasis  learni...             0.999700
# ...                                                 ...                  ...
# 8583   almost self confidence  feel like almost impo...             0.999800
# 8584    man  guess gotta knock back      mbti  type ...             0.998500
# 8585   hal   gel  one  blood moon  taken phone    wo...             0.999150
# 8586   like bilgepump  also late bloomer come dating...             0.999650
# 8587   happens   feel compelled help people sometime...             0.998650
#
#       positive--sentiment  negative--sentiment  neutral--sentiment  \
# 0                0.416667             0.133020            0.638860
# 1                0.588710             0.131455            0.505808
# 2                0.353495             0.294210            0.579725
# 3                0.431452             0.256651            0.543823
# 4                0.426075             0.172144            0.605069
# ...                   ...                  ...                 ...
# 8583             0.447581             0.172144            0.588173
# 8584             0.301075             0.170579            0.703273
# 8585             0.306452             0.178404            0.694826
# 8586             0.358871             0.115806            0.694826
# 8587             0.310484             0.200313            0.676874
#
#       question_mark  exclamation_marks  colon  emoji   word  unique_word  \
# 0              0.08               0.22   0.32   0.08  30.98        14.92
# 1              0.12               0.36   0.14   0.00  28.58        12.72
# 2              0.32               0.10   0.50   0.20  22.28        11.76
# 3              0.04               0.00   0.00   0.00  34.36        15.38
# 4              0.64               0.48   0.14   0.00  23.90        12.66
# ...             ...                ...    ...    ...    ...          ...
# 8583           0.24               0.26   0.24   0.00  29.12        13.30
# 8584           0.10               0.00   0.08   0.00  28.38        12.20
# 8585           0.16               0.08   0.10   0.00  30.92        15.36
# 8586           0.04               0.14   0.08   0.00  27.54        13.64
# 8587           0.52               0.26   0.04   0.00  30.00        14.08
#
#       links  images_count
# 0      0.04          0.00
# 1      0.02          0.00
# 2      0.06          0.04
# 3      0.02          0.00
# 4      0.50          0.04
# ...     ...           ...
# 8583   0.08          0.00
# 8584   0.02          0.00
# 8585   0.02          0.00
# 8586   0.36          0.34
# 8587   0.00          0.00
#
# [8588 rows x 19 columns]

# %%
from sklearn.model_selection  import train_test_split

# %%
import numpy as np

# %%
y=personality['Extrovert']
x=personality[['compound--sentiment','positive--sentiment','negative--sentiment','neutral--sentiment']]

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[1986    0]
#  [ 591    0]]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87      1986
#            1       0.00      0.00      0.00       591
#
#     accuracy                           0.77      2577
#    macro avg       0.39      0.50      0.44      2577
# weighted avg       0.59      0.77      0.67      2577
